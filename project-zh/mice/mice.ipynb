# %%
library(readxl)                                                                                                                                                                                                                                                                
library(dplyr)
install.packages("mice")
library(mice)

# 读取Excel文件
file_path <- "C:\\Users\\fsyan\\Desktop\\副本数据 - 副本.xlsx"
df <- read_excel(file_path, sheet = "Sheet1")
imp_data <- mice(df, #数据集
                 method = "rf", #随机森林 
                 m=5, # 5次插补
                 printFlag = FALSE #不显示历史记录
                 )
complete(imp_data)
# Out:
# Warning message:
# "package 'mice' is in use and will not be installed"
#     time status
# 1     80 1
# 2    459 1
# 3    295 1
# 4    315 1
# 5    237 1
# 6     80 1
# 7   1784 0
# 8    811 1
# 9    138 1
# 10    76 1
# 11   389 1
# 12   307 1
# 13   493 0
# 14    92 1
# 15   503 0
# 16   526 0
# 17   144 1
# 18   215 1
# 19   342 1
# 20   333 1
# 21   650 0
# 22   712 1
# 23   530 1
# 24   209 1
# 25   629 1
# 26   181 1
# 27   683 1
# 28   608 1
# 29   192 1
# 30   287 1
# ⋮   ⋮    ⋮
# 126  214 1
# 127  248 1
# 128  234 1
# 129 1694 1
# 130  213 1
# 131  337 1
# 132  281 1
# 133  440 1
# 134  107 1
# 135  188 1
# 136   89 1
# 137  180 1
# 138 1267 1
# 139  321 1
# 140  380 1
# 141  193 1
# 142  167 1
# 143  430 1
# 144  330 1
# 145   96 1
# 146  459 1
# 147  354 1
# 148  285 1
# 149  208 1
# 150  266 1
# 151  253 1
# 152  378 0
# 153  329 1
# 154  303 1
# 155  344 0
